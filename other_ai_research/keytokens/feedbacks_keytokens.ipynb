# %% [markdown]
# # Выделение ключевых фраз. Отзывы (1-110 пользователь)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 10

# %% [markdown]
# ## Выгрузка, группировка и склейка отзывов
#
# Отзывы предварительно приведены к нижнему регистру, очищены от пунктуации, лишних пробелов и стоп-слов, лемматизированы

# %%
electives = pd.read_csv('drive/MyDrive/ОБЩЕЕ/Отзывус/AI/key_tokens/data/feedbacks_dropna_sorted_cleaned.csv', sep=';')
electives
# Out:
#             На какой электив вы хотите оставить отзыв?  \
# 0            3D и медийная реклама в программе 3DS MAX
# 1            Python - программная среда для аналитиков
# 2    R для лингвистов: программирование и анализ да...
# 3    Адаптация населения России к трудностям револю...
# 4                                    Анализ данных в R
# ..                                                 ...
# 192  Экология. Технологии. Аниме/Ecology. Technolog...
# 193                                           Эристика
# 194                                           Эристика
# 195                                           Эристика
# 196                  Юридическое сопровождение бизнеса
#
#           Какие ещё названия этого электива вы знаете?  \
# 0    3д, 3d, 3 д, 3 d, 3д моделирование, 3д проекти...
# 1                                                  NaN
# 2                                 Программирование в R
# 3                                            Адаптация
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                                ЮСБ
#
#      На сколько бы вы оценили этот электив?  \
# 0                                         4
# 1                                         5
# 2                                         1
# 3                                         5
# 4                                         4
# ..                                      ...
# 192                                       4
# 193                                       5
# 194                                       4
# 195                                       5
# 196                                       2
#
#                        Введите текст отзыва на электив  \
# 0    Чисто основы основ 3д моделинга, для тех кто в...
# 1                                          Кайфы ловлю
# 2    Проходил он онлайн на платформе openedu.ru. По...
# 3    Супер пушка класс препод супер интересные исто...
# 4    Анализируем данные на ЯП R, на автомат выйти с...
# ..                                                 ...
# 192  Плюс в том, что можешь пройти когда хочешь, ми...
# 193  Помимо коммуникативных навыков, даёт неплохой ...
# 194  Электив, на котором учат искусству спора и пуб...
# 195  Классный электив для любителей поработать язык...
# 196  Залупа , препод обьясняет как детскому саду и ...
#
#     Чем вы руководствовались при выборе этого электива?  \
# 0    Описанием электива в карточке МУП;Названием эл...
# 1               Названием электива;Тематикой электива;
# 2                                      Попал случайно;
# 3    Тематикой электива;Списком преподавателей;Отзы...
# 4                                              Наугад;
# ..                                                 ...
# 192  Описанием электива в карточке МУП;Названием эл...
# 193       Тематикой электива;Отзывами других студенов;
# 194  Описанием электива в карточке МУП;Названием эл...
# 195  Списком преподавателей;Отзывами других студено...
# 196  Описанием электива в карточке МУП;Названием эл...
#
#                     Чего вы ожидали от этого электива?  \
# 0    Введение в основы 3д моделинга, постановки сце...
# 1                                               Кайфов
# 2                     Я совсем не хотела его проходить
# 3                                     То что и получил
# 4                                                  NaN
# ..                                                 ...
# 192                        Просмотра интересного аниме
# 193                что мои навыки "спорщика" улучшатся
# 194                                                NaN
# 195                               Интересные дискуссии
# 196                  Получение соответствующих навыков
#
#     Ваши ожидания от этого электива оправдались?  \
# 0                             Скорее да, чем нет
# 1                                             Да
# 2                                            Нет
# 3                                             Да
# 4                             Скорее нет, чем да
# ..                                           ...
# 192                           Скорее нет, чем да
# 193                                           Да
# 194                                           Да
# 195                                           Да
# 196                                          Нет
#
#               Что дало вам прохождение этого электива?  \
# 0    Определенно дал какие-то навыки в 3д. Теперь е...
# 1                                                Кайфы
# 2                         Ничего, только нервы помотал
# 3                                        Большой пенис
# 4                                                  NaN
# ..                                                 ...
# 192                                                NaN
# 193  Многие уже имеющиеся знания были систематизиро...
# 194  Непобедимость в спорах любой сложности. А вооб...
# 195  Понимание того, что главное в споре – не выясн...
# 196                                              Нихуя
#
#     Какой преподаватель вёл этот электив?  \
# 0               Мокроусов Сергей Иванович
# 1               Актаев Нуркен Ерболатович
# 2                         Курс шёл онлайн
# 3          Кононенко Анатолий Анатольевич
# 4                                     NaN
# ..                                    ...
# 192                                   NaN
# 193                                   NaN
# 194             Пупышева Ирина Николаевна
# 195             Пупышева Ирина Николаевна
# 196             Трухин Николай Валериевич
#
#      На сколько бы вы оценили этого преподавателя в рамках этого электива?
# 0                                                  5.0
# 1                                                  5.0
# 2                                                  2.0
# 3                                                  5.0
# 4                                                  5.0
# ..                                                 ...
# 192                                                4.0
# 193                                                5.0
# 194                                                5.0
# 195                                                5.0
# 196                                                1.0
#
# [197 rows x 10 columns]

# %%
print("Элективов:", len(electives['На какой электив вы хотите оставить отзыв?'].unique()))

symbols = electives['Введите текст отзыва на электив'].apply(lambda t: len(t))
print("Средняя длинна отзыва:", symbols.mean())
print("min/max:", symbols.min(), "|", symbols.max())

words = electives['Введите текст отзыва на электив'].str.split().apply(len)
print("Среднее кол-во слов в отзыве:", words.mean())
print("min/max:", words.min(), "|", words.max())
# Out:
# Элективов: 132
# Средняя длинна отзыва: 319.93908629441626
# min/max: 11 | 1354
# Среднее кол-во слов в отзыве: 47.213197969543145
# min/max: 2 | 222

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from string import punctuation
russian_stopwords = stopwords.words("russian")

# %%
def series_concat(series: pd.core.series.Series):
  text = ""
  for i in series:
    text += i + " "
  text = text.lower()
  return text

# %%
# !pip install -q gwpy

# %%
# %%capture
# !pip install natasha

from natasha import (
    Segmenter,
    MorphVocab,

    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,

    PER,
    NamesExtractor,
    DatesExtractor,
    MoneyExtractor,
    AddrExtractor,

    Doc
)

# %%
nat_segmenter = Segmenter()
nat_morph_vocab = MorphVocab()

nat_emb = NewsEmbedding()
nat_morph_tagger = NewsMorphTagger(nat_emb)
nat_syntax_parser = NewsSyntaxParser(nat_emb)
nat_ner_tagger = NewsNERTagger(nat_emb)

def lem_by_natasha_stopworded(text: str):
  text = text.lower()
  tokens = "".join([lit if lit not in punctuation else ' ' for lit in text]).split(" ")
  tokens = [token for token in tokens if len(token) > 0 and token not in russian_stopwords]
  text = " ".join(tokens)

  doc = Doc(text)
  doc.segment(nat_segmenter)
  doc.tag_morph(nat_morph_tagger)
  doc.parse_syntax(nat_syntax_parser)
  doc.tag_ner(nat_ner_tagger)

  new_text = ""
  for token in doc.tokens:
      token.lemmatize(nat_morph_vocab)
      new_text += token.lemma + " "

  return new_text

# %%
# %%time
electives_concat_feedbacks = pd.DataFrame(electives.groupby(["На какой электив вы хотите оставить отзыв?"])["Введите текст отзыва на электив"].apply(series_concat))
electives_concat_feedbacks["stopworded_lem_text"] = electives_concat_feedbacks["Введите текст отзыва на электив"].apply(lem_by_natasha_stopworded)
electives_concat_feedbacks["count_of_feedbacks"] = electives["На какой электив вы хотите оставить отзыв?"].value_counts().sort_index()
electives_concat_feedbacks.reset_index(drop=False, inplace=True)
electives_concat_feedbacks.columns = ["title", "concat_text", "stopworded_lem_text", "count"]
electives_concat_feedbacks
# Out:
# CPU times: user 2min 45s, sys: 46.1 s, total: 3min 31s
# Wall time: 3min 15s
#                                                  title  \
# 0            3D и медийная реклама в программе 3DS MAX
# 1            Python - программная среда для аналитиков
# 2    R для лингвистов: программирование и анализ да...
# 3    Адаптация населения России к трудностям револю...
# 4                                    Анализ данных в R
# ..                                                 ...
# 127  Экологические проблемы Тюменского региона: миф...
# 128                                           Экология
# 129  Экология. Технологии. Аниме/Ecology. Technolog...
# 130                                           Эристика
# 131                  Юридическое сопровождение бизнеса
#
#                                            concat_text  \
# 0    чисто основы основ 3д моделинга, для тех кто в...
# 1                                         кайфы ловлю
# 2    проходил он онлайн на платформе openedu.ru. по...
# 3    супер пушка класс препод супер интересные исто...
# 4    анализируем данные на яп r, на автомат выйти с...
# ..                                                 ...
# 127  проходит в соцгуме. преподы супер, у нас было ...
# 128  бесполезен, если вы не заинтересованы в ней. п...
# 129  занятий не было, просто давали просмотреть ани...
# 130  помимо коммуникативных навыков, даёт неплохой ...
# 131  залупа , препод обьясняет как детскому саду и ...
#
#                                    stopworded_lem_text  count
# 0    чисто основа основа 3 д моделинг тот шарит ску...      1
# 1                                          кайф ловля       1
# 2    проходить онлайн платформа openedu ru попасть ...      1
# 3    супер пушка класс препод супер интересный исто...      1
# 4    анализировать данные яп r автомат выйти сложно...      3
# ..                                                 ...    ...
# 127  проходить соцгум препод супер несколько препод...      1
# 128  бесполезный заинтересованы проходить онлайн по...      2
# 129  занятие просто давать просмотреть аниме платфо...      3
# 130  помимо коммуникативный навык давать неплохой т...      3
# 131   залупа препод обьяснять детский сад шутка тупой       1
#
# [132 rows x 4 columns]

# %%
electives_concat_feedbacks.to_csv("drive/MyDrive/ОБЩЕЕ/РСОДПО/AI/key_tokens/data/feedbacks_dropna_sorted_cleaned_stopsloved_natashed.csv")

# %% [markdown]
# ## ИЛИ Загрузка датасета, прошедшего через все круги Наташи и проч.

# %%
electives_concat_feedbacks = pd.read_csv('drive/MyDrive/ОБЩЕЕ/Отзывус/AI/key_tokens/data/feedbacks_dropna_sorted_cleaned_stopsloved_natashed.csv')
electives_concat_feedbacks
# Out:
#      Unnamed: 0                                              title  \
# 0             0          3D и медийная реклама в программе 3DS MAX
# 1             1          Python - программная среда для аналитиков
# 2             2  R для лингвистов: программирование и анализ да...
# 3             3  Адаптация населения России к трудностям револю...
# 4             4                                  Анализ данных в R
# ..          ...                                                ...
# 127         127  Экологические проблемы Тюменского региона: миф...
# 128         128                                           Экология
# 129         129  Экология. Технологии. Аниме/Ecology. Technolog...
# 130         130                                           Эристика
# 131         131                  Юридическое сопровождение бизнеса
#
#                                            concat_text  \
# 0    чисто основы основ 3д моделинга, для тех кто в...
# 1                                         кайфы ловлю
# 2    проходил он онлайн на платформе openedu.ru. по...
# 3    супер пушка класс препод супер интересные исто...
# 4    анализируем данные на яп r, на автомат выйти с...
# ..                                                 ...
# 127  проходит в соцгуме. преподы супер, у нас было ...
# 128  бесполезен, если вы не заинтересованы в ней. п...
# 129  занятий не было, просто давали просмотреть ани...
# 130  помимо коммуникативных навыков, даёт неплохой ...
# 131  залупа , препод обьясняет как детскому саду и ...
#
#                                    stopworded_lem_text  count
# 0    чисто основа основа 3 д моделинг тот шарит ску...      1
# 1                                          кайф ловля       1
# 2    проходить онлайн платформа openedu ru попасть ...      1
# 3    супер пушка класс препод супер интересный исто...      1
# 4    анализировать данные яп r автомат выйти сложно...      3
# ..                                                 ...    ...
# 127  проходить соцгум препод супер несколько препод...      1
# 128  бесполезный заинтересованы проходить онлайн по...      2
# 129  занятие просто давать просмотреть аниме платфо...      3
# 130  помимо коммуникативный навык давать неплохой т...      3
# 131   залупа препод обьяснять детский сад шутка тупой       1
#
# [132 rows x 5 columns]

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Векторизация всего корпуса склееных отзывов

# %%
cv = CountVectorizer()
word_count_vector = cv.fit_transform(electives_concat_feedbacks["stopworded_lem_text"])
word_count_vector.shape
# Out:
# (132, 2046)

# %% [markdown]
# Вычисление TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
tfidf_vectorizer_vectors = tfidf_vectorizer.fit_transform(electives_concat_feedbacks["stopworded_lem_text"])

# %% [markdown]
# TF-IDF для конкретно взятого электива

# %%
def tfidf_pred(el_index: int):
  document = tfidf_vectorizer.transform([lem_by_natasha_stopworded(electives_concat_feedbacks["concat_text"][el_index])])
  df = pd.DataFrame(document.T.todense(), index=tfidf_vectorizer.get_feature_names(), columns=["tfidf"])
  df = df.sort_values(by=["tfidf"], ascending=False)
  return ", ".join([i for i in df.head(10).index])

# %%
# %%time
tfidf_pred(5)
# Out:
# CPU times: user 49.7 ms, sys: 22.4 ms, total: 72.1 ms
# Wall time: 81.1 ms
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 'данные, ами, приобрести, чат, банк, сравнение, телеграмма, пользоваться, огромный, рамках'

# %% [markdown]
# ## YAKE
# https://doi.org/10.1016/j.ins.2019.09.013

# %%
# !pip install yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 KB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from yake) (2.8.8)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 KB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from yake) (1.21.6)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from yake) (0.8.10)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.8/dist-packages (from yake) (7.1.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from segtok->yake) (2022.6.2)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp38-cp38-linux_x86_64.whl size=70618 sha256=3d7d6063e07a798ffca4db8e448ed4abe04ad96db8eb60dc0b9eaba8d71751ef
#   Stored in directory: /root/.cache/pip/wheels/f1/c7/3c/4c83132de76359e3a429fd09c08995945ca96c5290a41651d3
# Successfully built jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8

# %%
import yake

# %%
yake_extractor = yake.KeywordExtractor(
    lan = "ru",
    n = 5,
    dedupLim = 0.3,
    top = 10
)

# %%
def yake_pred(el_index: int):
  result = ""
  for i in yake_extractor.extract_keywords(electives_concat_feedbacks["concat_text"][el_index])[::-1]:
     result += i[0] + ", "
  return result

# %%
# %%time
yake_pred(5)
# Out:
# CPU times: user 304 ms, sys: 3.62 ms, total: 308 ms
# Wall time: 396 ms
# 'excel, сайты с определенными данными, какими банками данных пользоваться, достаточно информации в рамках электива, огромным плюсом по сравнению, сравнению с другими моок-ами, задавать вопросы по заданиям, имелся чат в телеграмме, приобрела новые навыки в excel, легко закрыться, '

# %% [markdown]
# ## RAKE
# https://www.researchgate.net/publication/227988510_Automatic_Keyword_Extraction_from_Individual_Documents
# https://github.com/csurfer/rake-nltk

# %% [markdown]
# ОЧИСТКА ОТ ПУНКТУАЦИИ?!

# %%
# !pip install rake-nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rake-nltk in /usr/local/lib/python3.8/dist-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.8/dist-packages (from rake-nltk) (3.7)
# ERROR: Operation cancelled by user

# %%
from string import punctuation
punct = [i for i in punctuation]
punct
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from rake_nltk import Rake
r = Rake(min_length=2, punctuations=punctuation, language="russian")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def rake_pred(el_index: int):
  result = ""
  r.extract_keywords_from_text(electives_concat_feedbacks["concat_text"][el_index])
  for i in r.get_ranked_phrases()[:10]:
     result += i + ", "
  return result

# %%
# %%time
rake_pred(5).split(",")
# Out:
# CPU times: user 13 ms, sys: 2.86 ms, total: 15.9 ms
# Wall time: 32.4 ms
# ['какими банками данных пользоваться',
#  ' приобрела новые навыки',
#  ' предоставлено достаточно информации',
#  ' рамках электива',
#  ' определенными данными',
#  ' огромным плюсом',
#  ' некоторыми заданиями',
#  ' нам нужно',
#  ' найти сайты',
#  ' легко закрыться',
#  ' ']

# %% [markdown]
# ## python keyphrase extraction (PKE): TextRank

# %%
# %%capture
# !pip install git+https://github.com/boudinfl/pke.git
# !python -m spacy download ru_core_news_md

# %%
import pke, ru_core_news_md
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# !pip install scipy==1.8.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.8.0
#   Downloading scipy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scipy==1.8.0) (1.21.6)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed scipy-1.8.0

# %%
def textrank_pred(el_index: int):
  result = ""
  extractor = pke.unsupervised.TextRank()
  extractor.load_document(input=electives_concat_feedbacks["concat_text"][el_index], language="ru")
  extractor.candidate_selection()
  extractor.candidate_weighting()
  for i in extractor.get_n_best(n=10):
     result += i[0] + ", "
  return result

# %%
# %%time
textrank_pred(5)
# Out:
# CPU times: user 2.63 s, sys: 783 ms, total: 3.41 s
# Wall time: 3.43 s
# 'банками данных, определенными данными, рамках электива, другими моок-ами, огромным плюсом, новые навыки, информации, сайты, нужно, проблемы, '

# %% [markdown]
# ## KeyBERT
# https://doi.org/10.5281/zenodo.4461265

# %%
# %%capture
# !pip install transformers sentencepiece

# %%
import torch
from transformers import AutoModel
# bert_model = AutoModel.from_pretrained("cointegrated/rubert-tiny")
bert_model = AutoModel.from_pretrained("DeepPavlov/rubert-base-cased-conversational")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased-conversational were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# %%capture
# !pip install keybert

# %%
from keybert import KeyBERT

# %%
kw_model = KeyBERT(model=bert_model)

# %%
def keybert_pred(el_index: int):
  result = ""
  for i in kw_model.extract_keywords(electives_concat_feedbacks["concat_text"][el_index],
                                     keyphrase_ngram_range=(3, 6),
                                     stop_words=None,
                                     use_mmr=True, diversity=0.9,
                                     top_n=10)[::-1]:
    result += i[0] + ", "
  return result

# %%
# %%time
keybert_pred(130).split(",")
# Out:
# CPU times: user 231 ms, sys: 12.5 ms, total: 243 ms
# Wall time: 239 ms
# ['довольно интересная штука классный',
#  ' разбирали различные виды',
#  ' на котором учат искусству',
#  ' дискуссий стратегии тактики',
#  ' для любителей поработать языком',
#  ' выступлениям придется много',
#  ' даёт неплохой толчок для развития логики',
#  ' навыков даёт неплохой толчок для развития',
#  ' котором учат искусству спора',
#  ' так же психологии общения электив',
#  ' ']

# %% [markdown]
# ## Сравнение методов по различным элективам

# %%
electives_concat_feedbacks.sort_values("count", ascending=False)["count"]
# Out:
# 57     6
# 82     5
# 92     5
# 95     5
# 124    5
#       ..
# 47     1
# 46     1
# 44     1
# 42     1
# 131    1
# Name: count, Length: 132, dtype: int64

# %%
sum(electives_concat_feedbacks.sort_values("count", ascending=False)["count"])
# Out:
# 197

# %%
el_indeces = list(electives_concat_feedbacks.sort_values("count", ascending=False).index)
predictors = {"TFIDF": tfidf_pred,
              "YAKE": yake_pred,
              "TextRank": textrank_pred,
              "KeyBERT": keybert_pred,
              "RAKE": rake_pred}

# %%
el_indeces = list(electives_concat_feedbacks.sort_values("count", ascending=False).index)
predictors = {"KeyBERT": keybert_pred}

# %%
predictions = {"Titles": [],
               "Feedbacks": [],
               "TFIDF": [],
              "YAKE": [],
              "TextRank": [],
              "KeyBERT": [],
               "RAKE": []}
for el_index in el_indeces:
  predictions["Titles"].append(electives_concat_feedbacks["title"][el_index])
  predictions["Feedbacks"].append(electives_concat_feedbacks["concat_text"][el_index])
  for predictor_name, predictor_method in predictors.items():
    predictions[predictor_name].append(predictor_method(el_index))

predictions = pd.DataFrame(predictions)
predictions
# Out:
#                                                 Titles  \
# 0    Литература фанфикшн: интерпретация классически...
# 1          Практическая риторика и теория аргументации
# 2                                       Психика и мозг
# 3                                   Психология общения
# 4                               Фото- и видеоискусство
# ..                                                 ...
# 127       Коммуникативная грамматика (английский язык)
# 128            Китайский для начинающих и продолжающих
# 129                Кинотекст: от искусства к арт-хаусу
# 130                                   Как читать книги
# 131                  Юридическое сопровождение бизнеса
#
#                                              Feedbacks  \
# 0    обсуждение канона, фанона, фанфиков, пейрингов...
# 1    преподаватель очень добрая девушка, любит свой...
# 2    проводили много интересных тестов нервной сист...
# 3    лекции - нудные, скучные, там другой преподава...
# 4    прикольный был преподаватель, учил правилам на...
# ..                                                 ...
# 127  изучаем времена, разговариваем, играем в игры....
# 128  если вам нравятся восточные языки, то вы точно...
# 129  тематика прикольная, очень здорово, что ты смо...
# 130  электив, на котором придётся очень много работ...
# 131  залупа , препод обьясняет как детскому саду и ...
#
#                                                  TFIDF  \
# 0    фанфик, лояльный, петров, литература, простой,...
# 1    выступление, выступать, очень, риторика, пожал...
# 2    тест, лекция, сложный, онлайн, ответ, итог, мо...
# 3    сериал, посмотреть, практика, преподаватель, г...
# 4    рассказывать, мы, семинар, фотоаппарат, лекция...
# ..                                                 ...
# 127  играть, разговаривать, игра, домашка, изучать,...
# 128  иероглиф, лаоши, восточный, достигать, запомин...
# 129  неожиданный, тестирование, удобный, прикольный...
# 130  изобразить, контекст, стихотворение, нарисоват...
# 131  тупой, сад, залупа, обьяснять, детский, шутка,...
#
#                                                   YAKE  \
# 0    пары, интересно, фанфиков, используемых для ан...
# 1    страх сцены, электив, раскрепощенными в общени...
# 2    электив, памяти, внимания, интересный, мозга, ...
# 3    деле изучаешь, преподаватель, лекции ходила к ...
# 4    лекции, кстати почему написано видео искусство...
# ..                                                 ...
# 127    домашки, игры, разговариваем, изучаем времена,
# 128  каких-то результатов, интересные, реально начи...
# 129  лекции, здорово, единственный минус, оказался ...
# 130  котором, сложно описать, творческие задания, и...
# 131  шутки, детскому, обьясняет, тупейшие, препод, ...
#
#                                               TextRank  \
# 0    преподавателя - петрова владимира владимирович...
# 1    следующие практические пары, подробной обратно...
# 2    интересных тестов нервной системы, обязательны...
# 3    других людях шикарный предмет, первую серию се...
# 4    весенний период обучения, подборе цветовой гам...
# ..                                                 ...
# 127                           домашки, игры, времена,
# 128  домашку(в основном, каких-то результатов, инте...
# 129  неожиданным - обязательное итоговое тестирован...
# 130  анализа стихотворений, отдельной рамке, слово ...
# 131    шутки тупейшие, детскому саду, препод, залупа,
#
#                                                KeyBERT  \
# 0    вкидывать свое мнение предлагать вселенную, ли...
# 1    тему лекций, на элективе читали лекции, на эле...
# 2    после прохождения тестов по лекциям, электив о...
# 3    предоставляются преподавателями всем советую, ...
# 4    кучу инфы на лекции но, учитывая предпочтения ...
# ..                                                 ...
# 127  нет домашки, игры нет, изучаем времена, игры н...
# 128  задания реально начинаешь запоминать фразы, де...
# 129  время лекции потом уже, тестирование прокторин...
# 130  рамке много анализа стихотворений, особенно пи...
# 131  саду шутки тупейшие, шутки тупейшие, залупа пр...
#
#                                                   RAKE
# 0    чтение фанфиков стало учёбой ?), которой пишут...
# 1    побороть « страх сцены »., каждые следующие пр...
# 2    лабораторные ), выполняли различные задания, и...
# 3    которые предоставляются преподавателями всем с...
# 4    кстати почему написано видео искусство остаётс...
# ..                                                 ...
# 127                                  изучаем времена,
# 128  реально начинаешь запоминать фразы, яна лаоши ...
# 129  который оказался супер неожиданным, обязательн...
# 130  каждое слово нужно изобразить, ставят баллы )....
# 131  шутки тупейшие, препод обьясняет, детскому саду,
#
# [132 rows x 7 columns]

# %%
predictions = {"Titles": [],
               "Feedbacks": [],
              "KeyBERT": []}
for el_index in el_indeces:
  predictions["Titles"].append(electives_concat_feedbacks["title"][el_index])
  predictions["Feedbacks"].append(electives_concat_feedbacks["concat_text"][el_index])
  for predictor_name, predictor_method in predictors.items():
    predictions[predictor_name].append(predictor_method(el_index))

predictions = pd.DataFrame(predictions)
predictions
# Out:
#                                                 Titles  \
# 0    Литература фанфикшн: интерпретация классически...
# 1          Практическая риторика и теория аргументации
# 2                                       Психика и мозг
# 3                                   Психология общения
# 4                               Фото- и видеоискусство
# ..                                                 ...
# 127       Коммуникативная грамматика (английский язык)
# 128            Китайский для начинающих и продолжающих
# 129                Кинотекст: от искусства к арт-хаусу
# 130                                   Как читать книги
# 131                  Юридическое сопровождение бизнеса
#
#                                              Feedbacks  \
# 0    обсуждение канона, фанона, фанфиков, пейрингов...
# 1    преподаватель очень добрая девушка, любит свой...
# 2    проводили много интересных тестов нервной сист...
# 3    лекции - нудные, скучные, там другой преподава...
# 4    прикольный был преподаватель, учил правилам на...
# ..                                                 ...
# 127  изучаем времена, разговариваем, играем в игры....
# 128  если вам нравятся восточные языки, то вы точно...
# 129  тематика прикольная, очень здорово, что ты смо...
# 130  электив, на котором придётся очень много работ...
# 131  залупа , препод обьясняет как детскому саду и ...
#
#                                                KeyBERT
# 0    взять другое дз, серьезно при прогулах занятий...
# 1    печа куча тройная спираль, поставит нормальное...
# 2    вшэ стоит начать, левому правому полушариям, к...
# 3    посмотрела все сезоны, не сильно энергозатратн...
# 4    марата губайдуллина очень классные, не будет п...
# ..                                                 ...
# 127  играем игры нет, игры нет домашки, изучаем вре...
# 128  каких то результатов нужно делать, вы точно не...
# 129  прикольная очень здорово, прокторингом конце п...
# 130  их проверяют за, тут сложно описать что именно...
# 131  саду шутки тупейшие, обьясняет как детскому, з...
#
# [132 rows x 3 columns]

# %%
predictions.to_csv("drive/MyDrive/ОБЩЕЕ/Отзывус/AI/key_tokens/data/feedbacks_tokens_predictions_KeyBERT_DeepPavlov.csv")
