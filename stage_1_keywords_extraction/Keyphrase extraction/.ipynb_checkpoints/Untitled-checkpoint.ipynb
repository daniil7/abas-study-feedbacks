# %%
import polars as pl
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from sentence_transformers import SentenceTransformer

# %%
df = pl.read_csv('courses_dataset.csv', separator=';').drop_nulls(['text'])
docs = list(df['text'])

# %%
topic_model = BERTopic(
    language='russian',
    embedding_model=SentenceTransformer('cointegrated/rubert-tiny2'),
    representation_model=[MaximalMarginalRelevance(diversity=0.3), KeyBERTInspired()],
    verbose=True
)

# %%
topics, probabilities = topic_model.fit_transform(docs)
# Out:
# 2023-12-11 15:48:05,532 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/324 [00:00<?, ?it/s]

# %%
topic_model.visualize_topics()

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                              Name  \
# 0      -1   6041               -1_php_kodland_egorovdigital_online
# 1       0    424       0_alicekanevskaya_uiux_kubernetes_balakhtin
# 2       1    297        1_egorovdigital_business_marketing_general
# 3       2    275  2_yandexpracticum_lingualeo_mbaintensive_todooru
# 4       3    252                  3_moscow_linuxe_linux_kubernetes
# ..    ...    ...                                               ...
# 77     76     10                                  76_100_10_25_120
# 78     77     10                                            77____
# 79     78     10                       78_uiux_40_gb_tutoronlineru
# 80     79     10                                     79_youtube___
# 81     80     10                             80_units_50_10_600700
#
#                                        Representation  \
# 0   [php, kodland, egorovdigital, online, javascri...
# 1   [alicekanevskaya, uiux, kubernetes, balakhtin,...
# 2   [egorovdigital, business, marketing, general, ...
# 3   [yandexpracticum, lingualeo, mbaintensive, tod...
# 4   [moscow, linuxe, linux, kubernetes, kardanstud...
# ..                                                ...
# 77                  [100, 10, 25, 120, hsk, , , , , ]
# 78                               [, , , , , , , , , ]
# 79  [uiux, 40, gb, tutoronlineru, exel, 11, 60, lo...
# 80                        [youtube, , , , , , , , , ]
# 81                [units, 50, 10, 600700, , , , , , ]
#
#                                   Representative_Docs
# 0   [Всем привет. Меня зовут Алексей, я с Нижнего ...
# 1   [На тренинге в формате выполнения домашних зад...
# 2   [На курс egorovdigital пришла чтобы разобратьс...
# 3   [Благодаря программе я смог добрать недостающи...
# 4   [Лексика всегда была обширной. Особенно хочу в...
# ..                                                ...
# 77  [Мой уровень HSK 3, всвязи с удаленкой и новым...
# 78  [Редко оставляю отзывы в принципе.. Но увидела...
# 79  [Всё хорошее отношение менеджеров заканчиваетс...
# 80  [Общие впечатления хорошие, напишу по пунктам ...
# 81  [Курс имеет хорошее соотношение теории и практ...
#
# [82 rows x 5 columns]
