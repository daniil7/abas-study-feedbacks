# %%
# !pip install rutermextract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 8.2 MB 7.8 MB/s
# ...
#   Created wheel for rutermextract: filename=rutermextract-0.3-py3-none-any.whl size=9721 sha256=3f8dec82316f2d01298f9f7a26339cc3eaa53d86312da4b753d28fbac4e45921
#   Stored in directory: /root/.cache/pip/wheels/81/67/ff/529dc5299885578aa82942e8ed7344bc77f99bce2a2b929e40
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=b4d9cea265451ed83591d9611f44c16e51e3ba26f7d48852d43bba56c082750d
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built rutermextract docopt
# ...

# %%
from rutermextract import TermExtractor
term_extractor = TermExtractor()
text = ''
text = ''
text = ' Преподаватель Петров В.В. - довольно лоялен, умеет заинтересовать предметом. И шутку вставит, и тему занятия раскроет. При этом он настроен серьезно, при прогулах занятий выведет за зачет и будет спрашивать по пропущенным темам. В целом курс больше подходит для тех, кто интересуется фанфиками с точки зрения литературы, чем социологии. Домашние задания достаточно простые, можно справиться за час точно. Многие статьи на английском языке, но не все обязательно читать, можно обойтись переводчиком или взять другое дз.  Было очень любопытно через увлечение фанфиками узнать что-то новое о литературоведении, написании текстов и сценариев. Закрыть было легко. Отдельно хочу отметить преподавателя - Петрова Владимира Владимировича, который был лоялен к студентам и интересно рассказывал материал.  Обсуждение канона, фанона, фанфиков, пейрингов и т.д Довольно интересно, если не пропускать пары и разбираться в терминологии. Можно вкидывать свое мнение + предлагать вселенную, по которой пишут фанфики.  Преподаватель не располагает к себе, почувствовала моральное давление и перевелась'
for term in term_extractor(text):
   print(term.normalized, term.count)
# Out:
# фанфики 3
# преподаватель 3
# точка зрения литературы 1
# петров владимира владимировича 1
# тема занятия 1
# пропущенный темы 1
# прогулы занятий 1
# обсуждение канона 1
# написание текстов 1
# моральное давление 1
# домашние задание 1
# английский язык 1
# шутка 1
# час 1
# целое 1
# фанфиковы 1
# фанон 1
# увлечение 1
# терминология 1
# сценарии 1
# студенты 1
# статья 1
# социология 1
# предмет 1
# петров 1
# переводчик 1
# пейринги 1
# пара 1
# мнение 1
# материал 1
# литературоведение 1
# курс 1
# зачёт 1
# вселенная 1
