# %%
import pandas as pd
import nltk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Загрузка словаря
# И его подготовка

# %%
dic = pd.read_csv('drive/MyDrive/ОБЩЕЕ/РСОДПО/AI/emotional/data/kartaslovsent.csv', sep=';')
dic
# Out:
#                term   tag  value   pstv   ngtv   neut  dunno  \
# 0            абажур  NEUT   0.08  0.185  0.037  0.580  0.198
# 1         аббатство  NEUT   0.10  0.192  0.038  0.578  0.192
# 2      аббревиатура  NEUT   0.08  0.196  0.000  0.630  0.174
# 3             абзац  NEUT   0.00  0.137  0.000  0.706  0.157
# 4         абиссинец  NEUT   0.28  0.151  0.113  0.245  0.491
# ...             ...   ...    ...    ...    ...    ...    ...
# 46122       ёмкость  NEUT   0.00  0.167  0.000  0.690  0.143
# 46123        ёрзать  NGTV  -0.54  0.050  0.446  0.397  0.107
# 46124      ёрничать  NGTV  -0.79  0.078  0.529  0.236  0.157
# 46125           ёрш  NEUT   0.16  0.224  0.072  0.576  0.128
# 46126         ёршик  NEUT   0.00  0.152  0.043  0.718  0.087
#
#        pstvNgtvDisagreementRatio
# 0                           0.00
# 1                           0.00
# 2                           0.00
# 3                           0.00
# 4                           0.19
# ...                          ...
# 46122                       0.00
# 46123                       0.00
# 46124                       0.00
# 46125                       0.00
# 46126                       0.00
#
# [46127 rows x 8 columns]

# %%
dic = dic[['term', 'tag', 'value', 'pstvNgtvDisagreementRatio']]
dic
# Out:
#                term   tag  value  pstvNgtvDisagreementRatio
# 0            абажур  NEUT   0.08                       0.00
# 1         аббатство  NEUT   0.10                       0.00
# 2      аббревиатура  NEUT   0.08                       0.00
# 3             абзац  NEUT   0.00                       0.00
# 4         абиссинец  NEUT   0.28                       0.19
# ...             ...   ...    ...                        ...
# 46122       ёмкость  NEUT   0.00                       0.00
# 46123        ёрзать  NGTV  -0.54                       0.00
# 46124      ёрничать  NGTV  -0.79                       0.00
# 46125           ёрш  NEUT   0.16                       0.00
# 46126         ёршик  NEUT   0.00                       0.00
#
# [46127 rows x 4 columns]

# %%
positives = dic[(dic == 'PSTV').any(axis=1)][['term', 'value']]
neutrals  = dic[(dic == 'NEUT').any(axis=1)][['term', 'value']]
negatives = dic[(dic == 'NGTV').any(axis=1)][['term', 'value']]

# %% [markdown]
# # Функции "определения" тональности

# %%
def determine1(row):
  pstv = 0
  neut = 0
  ngtv = 0
  if (row['lemm'] is not None):
    for word in row['lemm']:
      if word in positives.values:
        pstv += 1
      elif word in neutrals.values:
        neut += 1
      elif word in negatives.values:
        ngtv += 1
    # print([ngtv, neut, pstv])
    return [ngtv, neut, pstv].index(max([ngtv, neut, pstv]))
  else:
    return None

# %%
import numpy as np

def determine2(row, is_num=False):
  ngtv = 0
  neut = 0
  pstv = 0
  em_decode = ['NGTV', 'NEUT', 'PSTV']
  for index, word in dic[np.isin(dic, [row['lemm']]).any(axis=1)].iterrows():
    if word['tag'] == 'NGTV':
      ngtv += word['value']
    elif word['tag'] == 'NUET':
      neut += word['value']
    elif word['tag'] == 'PSTV':
      pstv += word['value']
  if (is_num):
    return [ngtv, neut, pstv].index(max([ngtv, neut, pstv]))
  else:
    return em_decode[[ngtv, neut, pstv].index(max([ngtv, neut, pstv]))]

# %% [markdown]
# # Работа с текстом

# %%
pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 1.8 MB/s
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 6.7 MB/s
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=e87bfce1c1d10ed2f4439925f3a4a6a709e36098d095615d38e3b37c7a42b8ed
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
import re
from pymorphy2 import MorphAnalyzer
from nltk.corpus import stopwords
nltk.download('stopwords')

patterns = "[A-Za-z0-9!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-]+"
stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

def lemmatize(doc):
    doc = re.sub(patterns, ' ', doc)
    tokens = []
    for token in doc.split():
        if token and token not in stopwords_ru:
            token = token.strip()
            token = morph.normal_forms(token)[0]
            
            tokens.append(token)
    if len(tokens) > 2:
        return tokens
    return None
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# df = pd.read_csv('drive/MyDrive/ОБЩЕЕ/РСОДПО/AI/key_tokens/data/feedbacks_dropna_sorted_cleaned.csv', sep=';')[['На какой электив вы хотите оставить отзыв?', 'Введите текст отзыва на электив', 'На сколько бы вы оценили этот электив?', 'Ваши ожидания от этого электива оправдались?', 'На сколько бы вы оценили этого преподавателя в рамках этого электива?']]
df = pd.read_csv('drive/MyDrive/ОБЩЕЕ/РСОДПО/AI/key_tokens/data/feedbacks_dropna_sorted_cleaned.csv', sep=';')[['На какой электив вы хотите оставить отзыв?', 'Введите текст отзыва на электив']]
corpus = df['Введите текст отзыва на электив']

# %%
# %%time
df['lemm'] = corpus.apply(lambda x: lemmatize(x))
df['emote'] = df.apply(determine1, axis = 1)
# ngtv, neut, pstv
# Out:
# CPU times: user 40.7 s, sys: 113 ms, total: 40.8 s
# Wall time: 53.3 s

# %%
df.drop('lemm', axis=1)
# Out:
#             На какой электив вы хотите оставить отзыв?  \
# 0            3D и медийная реклама в программе 3DS MAX
# 1            Python - программная среда для аналитиков
# 2    R для лингвистов: программирование и анализ да...
# 3    Адаптация населения России к трудностям револю...
# 4                                    Анализ данных в R
# ..                                                 ...
# 192  Экология. Технологии. Аниме/Ecology. Technolog...
# 193                                           Эристика
# 194                                           Эристика
# 195                                           Эристика
# 196                  Юридическое сопровождение бизнеса
#
#                        Введите текст отзыва на электив  emote
# 0    Чисто основы основ 3д моделинга, для тех кто в...    1.0
# 1                                          Кайфы ловлю    NaN
# 2    Проходил он онлайн на платформе openedu.ru. По...    1.0
# 3    Супер пушка класс препод супер интересные исто...    2.0
# 4    Анализируем данные на ЯП R, на автомат выйти с...    1.0
# ..                                                 ...    ...
# 192  Плюс в том, что можешь пройти когда хочешь, ми...    1.0
# 193  Помимо коммуникативных навыков, даёт неплохой ...    2.0
# 194  Электив, на котором учат искусству спора и пуб...    1.0
# 195  Классный электив для любителей поработать язык...    1.0
# 196  Залупа , препод обьясняет как детскому саду и ...    1.0
#
# [197 rows x 3 columns]

# %%
# %%time
df['lemm'] = corpus.apply(lambda x: lemmatize(x))
df['emote'] = df.apply(determine2, axis = 1)
# ngtv, neut, pstv
# Out:
# CPU times: user 35.1 s, sys: 116 ms, total: 35.2 s
# Wall time: 37.6 s

# %%
df.drop('lemm', axis=1)
# Out:
#             На какой электив вы хотите оставить отзыв?  \
# 0            3D и медийная реклама в программе 3DS MAX
# 1            Python - программная среда для аналитиков
# 2    R для лингвистов: программирование и анализ да...
# 3    Адаптация населения России к трудностям револю...
# 4                                    Анализ данных в R
# ..                                                 ...
# 192  Экология. Технологии. Аниме/Ecology. Technolog...
# 193                                           Эристика
# 194                                           Эристика
# 195                                           Эристика
# 196                  Юридическое сопровождение бизнеса
#
#                        Введите текст отзыва на электив emote
# 0    Чисто основы основ 3д моделинга, для тех кто в...  PSTV
# 1                                          Кайфы ловлю  NGTV
# 2    Проходил он онлайн на платформе openedu.ru. По...  PSTV
# 3    Супер пушка класс препод супер интересные исто...  PSTV
# 4    Анализируем данные на ЯП R, на автомат выйти с...  PSTV
# ..                                                 ...   ...
# 192  Плюс в том, что можешь пройти когда хочешь, ми...  NGTV
# 193  Помимо коммуникативных навыков, даёт неплохой ...  PSTV
# 194  Электив, на котором учат искусству спора и пуб...  PSTV
# 195  Классный электив для любителей поработать язык...  PSTV
# 196  Залупа , препод обьясняет как детскому саду и ...  PSTV
#
# [197 rows x 3 columns]

# %% [markdown]
# # F1-мера

# %%
from sklearn.metrics import f1_score

# %%
test = pd.read_csv('drive/MyDrive/ОБЩЕЕ/РСОДПО/AI/emotional/data/train.csv', sep=',', nrows=10000, on_bad_lines='skip')
test
# Out:
#       Unnamed: 0                                               text  sentiment
# 0          21098  .с.,и спросил его:  о Посланник Аллаха!Ты пори...          1
# 1          21099  Роднее всех родных Попала я в ГКБ №8 еще в дек...          1
# 2          21100  Непорядочное отношение к своим работникам Рабо...          2
# 3          21101  ). Отсутствуют нормативы, Госты и прочее, что ...          1
# 4          21102             У меня машина в руках 5 лет и это п...          1
# ...          ...                                                ...        ...
# 9995       31093  Огромное спасибо врачам и медсёстрам 6-го акуш...          1
# 9996       31094  Заведение приличное , только пить пиво нельзя ...          0
# 9997       31095  Сейчас мы тут, номер 7108 с видом на дорогу) з...          1
# 9998       31096  Врач Коваленченко, грубое отношение к пациента...          2
# 9999       31097  Вылечили зуб и подняли настроение Хочу выразит...          1
#
# [10000 rows x 3 columns]

# %%
test = test.replace({'sentiment' : { 2 : 0, 0 : 1, 1 : 2}})
# NEUT, PSTV, NGTV -> NGTV, NEUT, PSTV

# %%
corpus = test['text']

# %%
# %%time
test['lemm'] = corpus.apply(lambda x: lemmatize(x))
test['emote'] = test.apply(lambda x: determine2(x, is_num=True), axis = 1)
# ngtv, neut, pstv
# Out:
# CPU times: user 1h 14min 42s, sys: 16.3 s, total: 1h 14min 58s
# Wall time: 1h 15min 6s

# %%
test.drop('lemm', axis=1)
# Out:
#       Unnamed: 0                                               text  \
# 0          21098  .с.,и спросил его:  о Посланник Аллаха!Ты пори...
# 1          21099  Роднее всех родных Попала я в ГКБ №8 еще в дек...
# 2          21100  Непорядочное отношение к своим работникам Рабо...
# 3          21101  ). Отсутствуют нормативы, Госты и прочее, что ...
# 4          21102             У меня машина в руках 5 лет и это п...
# ...          ...                                                ...
# 9995       31093  Огромное спасибо врачам и медсёстрам 6-го акуш...
# 9996       31094  Заведение приличное , только пить пиво нельзя ...
# 9997       31095  Сейчас мы тут, номер 7108 с видом на дорогу) з...
# 9998       31096  Врач Коваленченко, грубое отношение к пациента...
# 9999       31097  Вылечили зуб и подняли настроение Хочу выразит...
#
#       sentiment  emote
# 0             2      2
# 1             2      2
# 2             0      2
# 3             2      2
# 4             2      2
# ...         ...    ...
# 9995          2      2
# 9996          1      2
# 9997          2      2
# 9998          0      2
# 9999          2      2
#
# [10000 rows x 4 columns]

# %%
test['sentiment'].value_counts()
# Out:
# 2    4856
# 1    2610
# 0    2534
# Name: sentiment, dtype: int64

# %%
y_true = test['sentiment']
y_pred = test['emote']

# %%
f1_score(y_true, y_pred, average='macro')
# Out:
# 0.2524931006246871

# %%
f1_score(y_true, y_pred, average='micro')
# Out:
# 0.4955

# %%
f1_score(y_true, y_pred, average='weighted')
# Out:
# 0.34683256696942927

# %% [markdown]
# На 10000 записей F1-мера составила:
# *    Macro | 0.2524931006246871
# *    Micro | 0.4955
# * Weighted | 0.34683256696942927
#
# Временные затраты 1 час 15 минут 6 секунд
#
# [CPU times: user 1h 14min 42s, sys: 16.3 s, total: 1h 14min 58s Wall time: 1h 15min 6s]

# %% [markdown]
# ПЛОХО и немного БОЛЬНО

# %% [markdown]
# # "Эмпирическая" мера

# %%
from sklearn.metrics import precision_recall_fscore_support as alotmetrics

# %%
of = pd.read_csv('https://docs.google.com/spreadsheets/d/1kD4JRC_nDcF2ysmXKgYTA6jNpUi3vdbSmJY99lJxZis/export?format=csv')[['text', 'y']].replace({'y' : { -1 : 'NGTV', 0 : 'NEUT', 1 : 'PSTV'}})
of.columns = ['text', 'true']
of
# Out:
#                                                   text  true
# 0                     Электив сам по себе скучноватый.  NGTV
# 1    Я не считаю, что полученные знания помогут мне...  NGTV
# 2               Преподаватель очень тихо ведёт лекцию.  NEUT
# 3    Преподаватель не пытается как-то ухудшить проц...  NEUT
# 4    Ничего не делаем, в конце 2 проекта, можно бра...  NEUT
# ..                                                 ...   ...
# 138  Такая теория никак не поможет ребятам заинтере...  NGTV
# 139  Было бы гораздо лучше, будь преподаватель с ка...  NGTV
# 140  Или это преподавали бы люди с кафедры предприн...  NEUT
# 141  Толку учить пользоваться программой, где самый...  NGTV
# 142  Педагог макимально пофигистичная, ученики ей а...  NGTV
#
# [143 rows x 2 columns]

# %%
# %%time
of['lemm'] = corpus.apply(lambda x: lemmatize(x))
of['pred'] = of.apply(determine2, axis = 1)
# ngtv, neut, pstv
# Out:
# CPU times: user 24.7 s, sys: 92.8 ms, total: 24.8 s
# Wall time: 25.9 s

# %%
of
# Out:
#                                                   text  true  \
# 0                     Электив сам по себе скучноватый.  NGTV
# 1    Я не считаю, что полученные знания помогут мне...  NGTV
# 2               Преподаватель очень тихо ведёт лекцию.  NEUT
# 3    Преподаватель не пытается как-то ухудшить проц...  NEUT
# 4    Ничего не делаем, в конце 2 проекта, можно бра...  NEUT
# ..                                                 ...   ...
# 138  Такая теория никак не поможет ребятам заинтере...  NGTV
# 139  Было бы гораздо лучше, будь преподаватель с ка...  NGTV
# 140  Или это преподавали бы люди с кафедры предприн...  NEUT
# 141  Толку учить пользоваться программой, где самый...  NGTV
# 142  Педагог макимально пофигистичная, ученики ей а...  NGTV
#
#                                                   lemm  pred
# 0    [чисто, основа, основа, далее, моделинга, тот,...  PSTV
# 1                                                 None  NGTV
# 2    [проходить, онлайн, платформа, попасть, курс, ...  PSTV
# 3    [супер, пушка, класс, препод, супер, интересны...  PSTV
# 4    [анализировать, дать, яп, автомат, выйти, слож...  PSTV
# ..                                                 ...   ...
# 138  [закрыться, легко, просто, посещать, занятие, ...  PSTV
# 139  [много, гость, предприниматель, иногда, дельны...  PSTV
# 140  [лекция, нудный, скучный, преподаватель, некот...  PSTV
# 141  [прекрасный, электив, помогать, разобраться, д...  PSTV
# 142  [шикарный, предмет, который, просто, разговари...  PSTV
#
# [143 rows x 4 columns]

# %%
print('Precision', 'Recall', 'F-score', 'HZ')
print(alotmetrics(of['true'], of['pred'], average='macro'))
print(alotmetrics(of['true'], of['pred'], average='micro'))
print(alotmetrics(of['true'], of['pred'], average='weighted'))
# Out:
# Precision Recall F-score HZ
# (0.4529262086513995, 0.36384845463609167, 0.2577684235142798, None)
# (0.3706293706293706, 0.3706293706293706, 0.3706293706293706, None)
# (0.4506218971867827, 0.3706293706293706, 0.25307044091574477, None)
